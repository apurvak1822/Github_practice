# %% [markdown]
# <a href="https://colab.research.google.com/github/apurvak1822/Github_practice/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step 1 :importing library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the data
data={"hours":[1,2,3,4,5],
      "marks":[50,60,80,90,100]}
df=pd.DataFrame(data)
print(df)
# Out:
#    hours  marks
# 0      1     50
# 1      2     60
# 2      3     80
# 3      4     90
# 4      5    100

# %%
x=df[["hours"]].values
y=df[["marks"]].values

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
slope=model.coef_[0]
intercept=model.intercept_

# %%
print(f"slope:{slope}")
print(f"Intercept (b):{intercept}")
print(f"Equation of the regression line: y={slope[0]:.2f} x + {intercept[0]:.2f}")
# Out:
# slope:[13.]
# Intercept (b):[37.]
# Equation of the regression line: y=13.00 x + 37.00

# %%
df['Predicted marks']=model.predict(x)

# %%
df.head()
# Out:
#    hours  marks  Predicted marks
# 0      1     50             50.0
# 1      2     60             63.0
# 2      3     80             76.0
# 3      4     90             89.0
# 4      5    100            102.0

# %%
plt.scatter(df['hours'],df['marks'],color='blue',label='Actual marks')

# %%
plt.plot(df['hours'],df['Predicted marks'],color='red',label='Regression Line')
plt.xlabel('Hours studied')
plt.ylabel('marks')
plt.title('Linear Regression:Hours vs marks')
plt.legend()
plt.show()
